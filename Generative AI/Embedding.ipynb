# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')

# %%
from langchain_openai import OpenAIEmbeddings

embed = OpenAIEmbeddings(model="text-embedding-3-large")
embed
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x0000021D4DC4D270>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x0000021D4DC2ECB0>, model='text-embedding-3-large', dimensions=None, deployment='text-embedding-ada-002', openai_api_version='', openai_api_base=None, openai_api_type='', openai_proxy='', embedding_ctx_length=8191, openai_api_key=SecretStr('**********'), openai_organization=None, allowed_special=None, disallowed_special=None, chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None, http_async_client=None, check_embedding_ctx_length=True)

# %%
text = "tutorial on openAI embedding"

# res = embed.embed_query(text)

# len(res) --> 3072

# %% [markdown]
# ## OLLAMA models for embeddings

# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embeddings = (
    OllamaEmbeddings(model="gemma2:2b")
)
embeddings
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='gemma2:2b', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader('speech.txt')
text_doc = loader.load()
text_doc
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='To the people of India, Dr APJ Abdul Kalam is no less than an inspiration.\n\nPeople had a great deal of admiration for him and addressed him as Sir APJ Abdul Kalam.\n\nThis article consists of 3 types of APJ Abdul Kalam Speech In English For Students.\n\nThe first one is a Long APJ Abdul Kalam Speech meant for students of class 9th and above.\n\nThe second one is the usually spoken APJ Abdul Kalam Speech In School for students of class 5th and above while the third one is 10 lines About Abdul Kalam Speech for students of Class 1 and above for easier understanding.\n\n')]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size =50, chunk_overlap=10)
final_split = text_splitter.split_documents(text_doc)

# %%
r1 =embeddings.embed_documents(
    [
        "Alpha is the first letter of greek alphabet",
        "Beta is the second letrter of greek alphabet",
    ]
)

# %%
len(r1[0])
# Out:
# 2304

# %%
embeddings.embed_query("What is the second letter of greek alphabhet")
# Out:
# [0.21715229749679565,
#  -0.9880523681640625,
#  -1.5142143964767456,
#  1.3138900995254517,
#  0.8916602730751038,
#  -1.1649194955825806,
#  1.9941611289978027,
#  -3.5700900554656982,
#  -1.3758059740066528,
#  0.8093312978744507,
#  -2.5962789058685303,
#  -0.45275577902793884,
#  -1.1423922777175903,
#  -0.6419057846069336,
#  0.8013603687286377,
#  -1.7030776739120483,
#  -3.7490241527557373,
#  -2.934427499771118,
#  -3.944730758666992,
#  -2.1681909561157227,
#  1.9603071212768555,
#  1.303623914718628,
#  -1.6715188026428223,
#  -0.29725193977355957,
#  3.553605794906616,
#  -0.535621166229248,
#  1.6787047386169434,
#  -0.4715285301208496,
#  -0.3296228051185608,
#  0.10417509078979492,
#  -1.366964340209961,
#  0.65086829662323,
#  -1.3914161920547485,
#  -1.7904560565948486,
#  -0.1861855536699295,
#  0.8741309642791748,
#  -0.7293490171432495,
#  0.2578946650028229,
#  0.877994179725647,
#  -2.3248214721679688,
#  -0.1487298160791397,
#  3.063455820083618,
# ...

# %%
len(r1[1])
# Out:
# 2304

# %% [markdown]
# ## Huggingface Embeddings

# %%
os.environ["HF_TOKEN"] = os.getenv("HF_TOKEN")

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from sentence_transformers import SentenceTransformer
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 2
#       1 from langchain_huggingface import HuggingFaceEmbeddings
# ----> 2 from sentence_transformers import SentenceTransformer
#
# File d:\ml\Generative AI\Gen_env\lib\site-packages\sentence_transformers\__init__.py:7
#       4 import importlib
#       5 import os
# ----> 7 from sentence_transformers.cross_encoder.CrossEncoder import CrossEncoder
#       8 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#       9 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File d:\ml\Generative AI\Gen_env\lib\site-packages\sentence_transformers\cross_encoder\__init__.py:1
# ----> 1 from .CrossEncoder import CrossEncoder
#       3 __all__ = ["CrossEncoder"]
#
# File d:\ml\Generative AI\Gen_env\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:7
# ...

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#
# File d:\ml\Generative AI\Gen_env\lib\site-packages\torch\__init__.py:148
#     146                 err = ctypes.WinError(ctypes.get_last_error())
#     147                 err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 148                 raise err
#     150     kernel32.SetErrorMode(prev_error_mode)
#     153 def _preload_cuda_deps(lib_folder, lib_name):
#
# OSError: [WinError 126] The specified module could not be found. Error loading "d:\ml\Generative AI\Gen_env\lib\site-packages\torch\lib\fbgemm.dll" or one of its dependencies.

# %%
embedding = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 embedding = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
#
# File d:\ml\Generative AI\Gen_env\lib\site-packages\langchain_huggingface\embeddings\huggingface.py:53, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      51 super().__init__(**kwargs)
#      52 try:
# ---> 53     import sentence_transformers  # type: ignore[import]
#      55 except ImportError as exc:
#      56     raise ImportError(
#      57         "Could not import sentence_transformers python package. "
#      58         "Please install it with `pip install sentence-transformers`."
#      59     ) from exc
#
# File d:\ml\Generative AI\Gen_env\lib\site-packages\sentence_transformers\__init__.py:7
#       4 import importlib
#       5 import os
# ...
