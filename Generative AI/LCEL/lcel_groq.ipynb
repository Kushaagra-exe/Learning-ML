# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroqimport os
from dotenv import load_dotenv
from langchain_groq import ChatGroq

# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq
