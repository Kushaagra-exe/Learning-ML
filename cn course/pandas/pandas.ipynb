# %%
# %pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd

# %%
iris = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
iris
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
print(type(iris))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df = iris.copy()

# %%
df.head(3)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa

# %%
df.columns = ['sl', 'sw', 'pl', 'pw', 'flower_type']

# %%
print(df.shape)
print(df.dtypes)
# Out:
# (149, 5)
# sl             float64
# sw             float64
# pl             float64
# pw             float64
# flower_type     object
# dtype: object

# %%
df.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.sl
print(df['sl'])
#same
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sl, Length: 149, dtype: float64

# %%
df.isnull() #returns bools
df.isnull().sum()
# Out:
# sl             0
# sw             0
# pl             0
# pw             0
# flower_type    0
# dtype: int64

# %%
df.iloc[1:4,2:4] #specific rows n cols
# Out:
#     pl   pw
# 1  1.3  0.2
# 2  1.5  0.2
# 3  1.4  0.2

# %%
df.tail()
# Out:
#       sl   sw   pl   pw     flower_type
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
a = df.drop(0)
a.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa

# %%
df.drop(0, inplace = True)
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa

# %%
df.index
# Out:
# RangeIndex(start=1, stop=149, step=1)

# %%
df.index[0], df.index[5]
# Out:
# (1, 6)

# %%
df.drop(df.index[0], inplace = True)
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa

# %%
df.drop(df.index[[0,1]], inplace = True)
df.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa

# %%
df[df.sl>5]
# Out:
#       sl   sw   pl   pw     flower_type
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# 9    5.4  3.7  1.5  0.2     Iris-setosa
# 13   5.8  4.0  1.2  0.2     Iris-setosa
# 14   5.7  4.4  1.5  0.4     Iris-setosa
# 15   5.4  3.9  1.3  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [117 rows x 5 columns]

# %%
df[df.flower_type == 'Iris-setosa']
df[df.flower_type == 'Iris-setosa'].describe()
# Out:
#               sl         sw         pl         pw
# count  45.000000  45.000000  45.000000  45.000000
# mean    5.022222   3.433333   1.471111   0.248889
# std     0.362998   0.391384   0.180432   0.112052
# min     4.300000   2.300000   1.000000   0.100000
# 25%     4.800000   3.200000   1.400000   0.200000
# 50%     5.000000   3.400000   1.500000   0.200000
# 75%     5.200000   3.700000   1.600000   0.300000
# max     5.800000   4.400000   1.900000   0.600000

# %%
# iloc -> index
# loc -> label

print(df.head())
print("\n\n")
print(df.iloc[0])
df.loc[2]
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa
#
#
#
# 5.1                    4.6
# 3.5                    3.1
# 1.4                    1.5
# 0.2                    0.2
# Iris-setosa    Iris-setosa
# Name: 2, dtype: object
# 5.1                    4.6
# 3.5                    3.1
# 1.4                    1.5
# 0.2                    0.2
# Iris-setosa    Iris-setosa
# Name: 2, dtype: object

# %%
df.loc[0]= [1,2,3,4,'Iris-setosa']
df.loc[149]= [1,2,3,4,'Iris-setosa']

# df.head()
df.tail()
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
# 0    1.0  2.0  3.0  4.0     Iris-setosa
# 149  1.0  2.0  3.0  4.0     Iris-setosa

# %%
df.reset_index()  # old index col will be added
# Out:
#      index  5.1  3.5  1.4  0.2     Iris-setosa
# 0        2  4.6  3.1  1.5  0.2     Iris-setosa
# 1        3  5.0  3.6  1.4  0.2     Iris-setosa
# 2        4  5.4  3.9  1.7  0.4     Iris-setosa
# 3        5  4.6  3.4  1.4  0.3     Iris-setosa
# 4        6  5.0  3.4  1.5  0.2     Iris-setosa
# ..     ...  ...  ...  ...  ...             ...
# 144    146  6.5  3.0  5.2  2.0  Iris-virginica
# 145    147  6.2  3.4  5.4  2.3  Iris-virginica
# 146    148  5.9  3.0  5.1  1.8  Iris-virginica
# 147      0  1.0  2.0  3.0  4.0     Iris-setosa
# 148    149  1.0  2.0  3.0  4.0     Iris-setosa
#
# [149 rows x 6 columns]

# %%
df.reset_index(drop=True, inplace = True)
df.head()
# index col not added and done on df dataframe
# Out:
#     sl   sw   pl   pw  flower_type
# 0  4.6  3.1  1.5  0.2  Iris-setosa
# 1  5.0  3.6  1.4  0.2  Iris-setosa
# 2  5.4  3.9  1.7  0.4  Iris-setosa
# 3  4.6  3.4  1.4  0.3  Iris-setosa
# 4  5.0  3.4  1.5  0.2  Iris-setosa

# %%
# del cols

df.drop('sl', axis=1) # you can add inplace = True
# Out:
#       sw   pl   pw     flower_type
# 0    3.1  1.5  0.2     Iris-setosa
# 1    3.6  1.4  0.2     Iris-setosa
# 2    3.9  1.7  0.4     Iris-setosa
# 3    3.4  1.4  0.3     Iris-setosa
# 4    3.4  1.5  0.2     Iris-setosa
# ..   ...  ...  ...             ...
# 144  3.0  5.2  2.0  Iris-virginica
# 145  3.4  5.4  2.3  Iris-virginica
# 146  3.0  5.1  1.8  Iris-virginica
# 147  2.0  3.0  4.0     Iris-setosa
# 148  2.0  3.0  4.0     Iris-setosa
#
# [149 rows x 4 columns]

# %%
del df['sl']

# %%
df.describe()
# Out:
#                sw          pl          pw
# count  149.000000  149.000000  149.000000
# mean     3.036242    3.796644    1.256376
# std      0.449957    1.739113    0.817819
# min      2.000000    1.000000    0.100000
# 25%      2.800000    1.600000    0.300000
# 50%      3.000000    4.400000    1.300000
# 75%      3.300000    5.100000    1.800000
# max      4.400000    6.900000    4.000000

# %%
df = iris.copy()
df.columns = ['sl', 'sw', 'pl', 'pw', 'flower_type']
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
# adding a col

df["diff_pl_pw"] = df["pl"] - df["pw"]

# %%
df.tail()
# Out:
#       sl   sw   pl   pw     flower_type  diff_pl_pw
# 144  6.7  3.0  5.2  2.3  Iris-virginica         2.9
# 145  6.3  2.5  5.0  1.9  Iris-virginica         3.1
# 146  6.5  3.0  5.2  2.0  Iris-virginica         3.2
# 147  6.2  3.4  5.4  2.3  Iris-virginica         3.1
# 148  5.9  3.0  5.1  1.8  Iris-virginica         3.3

# %% [markdown]
# ## Assignment

# %%
import pandas as pd
# Out:
# C:\Users\Kushaagra Mehta\AppData\Local\Temp\ipykernel_27060\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
iris_data = pd.read_csv("iris.csv")

# %%
df = iris_data.copy()

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
types = df['variety'].unique()
types
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
for i in types:
    print(i+" :",len(df[df['variety']==i]))
# Out:
# Setosa : 50
# Versicolor : 50
# Virginica : 50

# %%
df[df['variety']=='Virginica']
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 100           6.3          3.3           6.0          2.5  Virginica
# 101           5.8          2.7           5.1          1.9  Virginica
# 102           7.1          3.0           5.9          2.1  Virginica
# 103           6.3          2.9           5.6          1.8  Virginica
# 104           6.5          3.0           5.8          2.2  Virginica
# 105           7.6          3.0           6.6          2.1  Virginica
# 106           4.9          2.5           4.5          1.7  Virginica
# 107           7.3          2.9           6.3          1.8  Virginica
# 108           6.7          2.5           5.8          1.8  Virginica
# 109           7.2          3.6           6.1          2.5  Virginica
# 110           6.5          3.2           5.1          2.0  Virginica
# 111           6.4          2.7           5.3          1.9  Virginica
# 112           6.8          3.0           5.5          2.1  Virginica
# ...

# %%
# df[df['variety']=='Virginica' and df['petal.length']>1.5]

df[df['variety']=='Virginica'].loc[df['petal.length']>1.5]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 100           6.3          3.3           6.0          2.5  Virginica
# 101           5.8          2.7           5.1          1.9  Virginica
# 102           7.1          3.0           5.9          2.1  Virginica
# 103           6.3          2.9           5.6          1.8  Virginica
# 104           6.5          3.0           5.8          2.2  Virginica
# 105           7.6          3.0           6.6          2.1  Virginica
# 106           4.9          2.5           4.5          1.7  Virginica
# 107           7.3          2.9           6.3          1.8  Virginica
# 108           6.7          2.5           5.8          1.8  Virginica
# 109           7.2          3.6           6.1          2.5  Virginica
# 110           6.5          3.2           5.1          2.0  Virginica
# 111           6.4          2.7           5.3          1.9  Virginica
# 112           6.8          3.0           5.5          2.1  Virginica
# ...

# %% [markdown]
# ## Handline NAN

# %%
import numpy as np

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.iloc[2:4,1:3] = np.nan
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          NaN           NaN          0.2  Setosa
# 3           4.6          NaN           NaN          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   148.000000    148.000000   150.000000
# mean       5.843333     3.056081      3.789865     1.199333
# std        0.828066     0.438648      1.755525     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.325000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.dropna(inplace=True) # this removes the rows having nan values (requires inplace)

# %%
df.reset_index(drop = True, inplace = True)
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           5.0          3.6           1.4          0.2  Setosa
# 3           5.4          3.9           1.7          0.4  Setosa
# 4           4.6          3.4           1.4          0.3  Setosa

# %%
df.iloc[2:4,1:3] = np.nan
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           5.0          NaN           NaN          0.2  Setosa
# 3           5.4          NaN           NaN          0.4  Setosa
# 4           4.6          3.4           1.4          0.3  Setosa

# %%
# filling the nan values -> mean of col
# filling the nan values -> most occuring of col

df['sepal.width'].fillna(df['sepal.width'].mean(), inplace=True)
df['petal.length'].fillna(df['petal.length'].mean(), inplace=True)

df.head()
# Out:
# C:\Users\Kushaagra Mehta\AppData\Local\Temp\ipykernel_27060\837380142.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['sepal.width'].fillna(df['sepal.width'].mean(), inplace=True)
# C:\Users\Kushaagra Mehta\AppData\Local\Temp\ipykernel_27060\837380142.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# ## handling strings

# %%
df['Gender'] = 'Female'
df.iloc[0:10,5] = 'Male'

def f(s):
    if s == 'Male':
        return 0
    else:
        return 1

df['sex'] = df.Gender.apply(f)
del df['Gender']
df.tail()
# Out:
# C:\Users\Kushaagra Mehta\AppData\Local\Temp\ipykernel_27060\2406044186.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Male' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[0:10,5] = 'Male'
#      sepal.length  sepal.width  petal.length  petal.width    variety  sex
# 143           6.7          3.0           5.2          2.3  Virginica    1
# 144           6.3          2.5           5.0          1.9  Virginica    1
# 145           6.5          3.0           5.2          2.0  Virginica    1
# 146           6.2          3.4           5.4          2.3  Virginica    1
# 147           5.9          3.0           5.1          1.8  Virginica    1

# %%
terror = pd.read_csv("terrorismData.csv")

# %%
terror.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %%
jammu_kashmir_data = terror[terror['State'] == 'Jammu and Kashmir']
jammu_kashmir_data;

# %%
# attacks_city = jammu_kashmir_data.groupby('City').size().reset_index(name='Number_of_Attacks')
# attacks_city = jammu_kashmir_data.groupby('City').size()
attacks_city = jammu_kashmir_data.City.value_counts()
attacks_city
# Out:
# City
# Srinagar     657
# Sopore       102
# Unknown       86
# Anantnag      76
# Jammu         57
#             ...
# Bragam         1
# Narsu          1
# Lasjan         1
# Goriwan        1
# Lethapora      1
# Name: count, Length: 633, dtype: int64

# %%
filter_unkn = jammu_kashmir_data[jammu_kashmir_data['Group'] != 'Unknown']
a = filter_unkn['Group'].value_counts()
a
# Out:
# Group
# Hizbul Mujahideen (HM)            193
# Lashkar-e-Taiba (LeT)             165
# Muslim Separatists                113
# Kashmiri extremists                73
# Muslim Militants                   70
#                                  ...
# Afghan Merceneries                  1
# Minority Unity Forum                1
# Lashkari-e-Adam (Army of Adam)      1
# Al-Fatah                            1
# Ansar Ghazwat-ul-Hind               1
# Name: count, Length: 64, dtype: int64

# %%
a.idxmax()
# Out:
# 'Hizbul Mujahideen (HM)'

# %%
attacks_city.idxmax()
# Out:
# 'Srinagar'

# %%
print(f'City:{attacks_city.idxmax()}, Attacks:{attacks_city.max()}, Most active group:{a.idxmax()}')
# Out:
# City:Srinagar, Attacks:657, Most active group:Hizbul Mujahideen (HM)

# %%
print("Most attacks in country: ",terror.Country.value_counts().idxmax())
# Out:
# Most attacks in country:  Iraq

# %%
terror.groupby('Country').size()
# Out:
# Country
# Afghanistan    12731
# Albania           80
# Algeria         2743
# Andorra            1
# Angola           499
#                ...
# Yemen           3347
# Yugoslavia       203
# Zaire             50
# Zambia            62
# Zimbabwe         101
# Length: 205, dtype: int64

# %%
terror.Country.value_counts()
# Out:
# Country
# Iraq                   24636
# Pakistan               14368
# Afghanistan            12731
# India                  11960
# Colombia                8306
#                        ...
# International              1
# Wallis and Futuna          1
# South Vietnam              1
# Andorra                    1
# Antigua and Barbuda        1
# Name: count, Length: 205, dtype: int64
